# %%
import numpy as np
import torch
torch.set_printoptions(edgeitems=2, threshold=50)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/
# Out:
# /content/drive/MyDrive

# %%
# !git clone https://github.com/ikwak2/dlwpt-code.git
# Out:
# Cloning into 'dlwpt-code'...
# remote: Enumerating objects: 711, done.
# remote: Counting objects: 100% (8/8), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 711 (delta 1), reused 0 (delta 0), pack-reused 703
# Receiving objects: 100% (711/711), 176.82 MiB | 11.64 MiB/s, done.
# Resolving deltas: 100% (310/310), done.
# Checking out files: 100% (228/228), done.

# %%
# !cd /content/drive/MyDrive/dlwpt-code/p1ch4

# %%
pwd
# Out:
# '/content/drive/MyDrive/dlwpt-code'

# %%
cd /content/drive/MyDr

# %%
import os
os.listdir('/content/drive/MyDrive/dlwpt-code/data/p1ch4/volumetric-dicom/2-LUNG 3.0  B70f-04083')

# %%
import imageio

dir_path = "/content/drive/MyDrive/dlwpt-code/data/p1ch4/volumetric-dicom/2-LUNG 3.0  B70f-04083"
vol_arr = imageio.volread(dir_path, 'DICOM')
vol_arr.shape
# Out:
# 99/99 files (100.0%)
#   Found 1 correct series.
# 99/99  (100.0%)
# (99, 512, 512)

# %%
import imageio

dir_path = "../data/p1ch4/volumetric-dicom/2-LUNG 3.0  B70f-04083"
vol_arr = imageio.volread(dir_path, 'DICOM')
vol_arr.shape
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-21-749296e9afe5> in <module>
#       2
#       3 dir_path = "../data/p1ch4/volumetric-dicom/2-LUNG 3.0  B70f-04083"
# ----> 4 vol_arr = imageio.volread(dir_path, 'DICOM')
#       5 vol_arr.shape
#
# /usr/local/lib/python3.7/dist-packages/imageio/core/functions.py in volread(uri, format, **kwargs)
#     451
#     452     # Get reader and read first
# --> 453     reader = read(uri, format, "v", **kwargs)
#     454     with reader:
#     455         return reader.get_data(0)
#
# /usr/local/lib/python3.7/dist-packages/imageio/core/functions.py in get_reader(uri, format, mode, **kwargs)
#     170
#     171     # Create request object
# --> 172     request = Request(uri, "r" + mode, **kwargs)
#     173
#     174     # Get format
#
# ...

# %%
vol = torch.from_numpy(vol_arr).float()
vol = torch.unsqueeze(vol, 0)

vol.shape
# Out:
# torch.Size([1, 99, 512, 512])

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

plt.imshow(vol_arr[50])

# %%
vol_arr.shape
# Out:
# (99, 512, 512)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

plt.imshow(vol_arr[97])
